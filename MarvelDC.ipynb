# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
marvel = pd.read_csv('charcters_stats.csv')

# %%
marvel.columns
# Out:
# Index(['Name', 'Alignment', 'Intelligence', 'Strength', 'Speed', 'Durability',
#        'Power', 'Combat', 'Total'],
#       dtype='object')

# %%
marvel.value_counts()
# Out:
# Name        Alignment  Intelligence  Strength  Speed  Durability  Power  Combat  Total
# 3-D Man     good       50            31        43     32          25     52      233      1
# Nick Fury   good       75            11        23     42          25     100     276      1
# Mysterio I  bad        75            10        23     42          50     56      256      1
# Mystique    bad        75            12        23     64          58     74      306      1
# Namor       good       1             1         1      1           0      1       5        1
#                                                                                          ..
# ERG-1       good       1             1         1      1           0      1       5        1
# Ego         bad        88            80        83     99          71     28      449      1
# Elastigirl  good       38            32        12     90          20     14      206      1
# ...

# %%
marvel.head()
# Out:
#           Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0      3-D Man      good            50        31     43          32     25
# 1       A-Bomb      good            38       100     17          80     17
# 2   Abe Sapien      good            88        14     35          42     35
# 3     Abin Sur      good            50        90     53          64     84
# 4  Abomination       bad            63        80     53          90     55
#
#    Combat  Total
# 0      52    233
# 1      64    316
# 2      85    299
# 3      65    406
# 4      95    436

# %%
marvel.shape
# Out:
# (611, 9)

# %%
marvel['Alignment'].value_counts()
# Out:
# good       432
# bad        165
# neutral     11
# Name: Alignment, dtype: int64

# %%
# Characters with Good ALignment
alg_filt  = marvel['Alignment']  == 'good'
good_hero = marvel[alg_filt]

# %%
marvel.sort_values('Speed', ascending=False)
# Out:
#               Name Alignment  Intelligence  Strength  Speed  Durability  \
# 610           Zoom       bad            50        10    100          28
# 418           Nova      good            38        60    100         100
# 447    Quicksilver      good            63        28    100          60
# 82         Bizarro   neutral            75        95    100         100
# 333         Krypto      good             9        80    100          90
# ..             ...       ...           ...       ...    ...         ...
# 160     Cogliostro       bad             1         1      1           1
# 158           Clea      good             1         1      1           1
# 425      Overtkill       bad             1         1      1           1
# 426        Penance      good             1         1      1           1
# 334  Lady Bullseye       bad             1         1      1           1
#
#      Power  Combat  Total
# 610     72      28    288
# 418    100      25    423
# ...

# %%
good_hero.sort_values('Speed', ascending=False)
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 231       Flash III      good            63        10    100          60
# 304  Jack of Hearts      good            63        55    100          30
# 295         Impulse      good            50        10    100          60
# 525        Stardust      good            88        85    100         110
# 447     Quicksilver      good            63        28    100          60
# ..              ...       ...           ...       ...    ...         ...
# 280       Hellstorm      good             1         1      1           1
# 445         Quantum      good             1         1      1           1
# 277   Hawkwoman III      good             1         1      1           1
# 276    Hawkwoman II      good             1         1      1           1
# 405           Namor      good             1         1      1           1
#
#      Power  Combat  Total
# 231     83      32    348
# 304     70      30    348
# ...

# %%
good_hero.sort_values('Power',ascending=False)
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 609         Zatanna      good            75        10     23          28
# 546            Thor      good            69       100     92         100
# 511           Spawn      good            75        60     50          90
# 69    Beta Ray Bill      good            63        80     35          95
# 70         Beyonder      good            88       100     23         100
# ..              ...       ...           ...       ...    ...         ...
# 127       Bumbleboy      good             1         1      1           1
# 124  Brother Voodoo      good             1         1      1           1
# 415     Nite Owl II      good             1         1      1           1
# 120         Box III      good             1         1      1           1
# 100     Blaquesmith      good             1         1      1           1
#
#      Power  Combat  Total
# 609    100      56    292
# 546    100      85    546
# ...

# %%
# MAX Power Characters
good_max_power  =   good_hero.sort_values("Total",ascending=False)

# %%
good_max_power.head(10)
# Out:
#                   Name Alignment  Intelligence  Strength  Speed  Durability  \
# 361  Martian Manhunter      good           100       100     96         100
# 537           Superman      good           100       100    100         100
# 525           Stardust      good            88        85    100         110
# 546               Thor      good            69       100     92         100
# 536          Supergirl      good            94        98     92         100
# 417               Nova      good           100        85     67         101
# 251               Goku      good            56       100     75          90
# 306          Jean Grey      good           100        80     67         100
# 433            Phoenix      good           100        80     67         100
# 299           Iron Man      good           100        85     58          85
#
#      Power  Combat  Total
# 361    100      85    581
# 537     94      85    579
# 525    100      85    568
# ...

# %%
# Min Speed Characters with Good Alignment
min_speed_filt = marvel['Speed']==1
good_hero[min_speed_filt].head()
# Out:
# C:\Users\Kali\AppData\Local\Temp\ipykernel_10780\1606156101.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   good_hero[min_speed_filt].head()
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 7       Adam Strange      good             1         1      1           1
# 8          Agent  13      good             1         1      1           1
# 13      Alex Woolsly      good             1         1      1           1
# 15  Allan Quatermain      good             1         1      1           1
# 18    Ando Masahashi      good             1         1      1           1
#
#     Power  Combat  Total
# 7       0       1      5
# 8       0       1      5
# 13      0       1      5
# 15      0       1      5
# 18      0       1      5

# %%
plt.figure(figsize=(8,5))
plt.bar(list(good_max_power['Name'])[0:5] , list(good_max_power['Total'])[0:5],color='g')
plt.show()

# %%
# Characters with bad Alignment
bad_hero_filt  = marvel['Alignment']=='bad'

# %%
bad_hero  =  marvel[bad_hero_filt]

# %%
bad_hero
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 4       Abomination       bad            63        80     53          90
# 5           Abraxas       bad            88       100     83          99
# 11       Air-Walker       bad            50        85    100          85
# 16            Amazo       bad            75       100    100         100
# 17             Ammo       bad             1         1      1           1
# ..              ...       ...           ...       ...    ...         ...
# 586            Warp       bad            38        10     23          28
# 590       Weapon XI       bad             1         1      1           1
# 593  Willis Stryker       bad            38        16     23          28
# 605     Yellow Claw       bad             1         1      1           1
# 610            Zoom       bad            50        10    100          28
#
#      Power  Combat  Total
# 4       55      95    436
# 5      100      56    526
# ...

# %%
bad_hero.sort_values(by='Speed',ascending=False)
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 610             Zoom       bad            50        10    100          28
# 11        Air-Walker       bad            50        85    100          85
# 16             Amazo       bad            75       100    100         100
# 535   Superboy-Prime       bad            94       100    100         100
# 242      General Zod       bad            94       100     96         100
# ..               ...       ...           ...       ...    ...         ...
# 256  Granny Goodness       bad             1         1      1           1
# 254      Goliath III       bad             1         1      1           1
# 503         Siren II       bad             1         1      1           1
# 154      Cheetah III       bad             1         1      1           1
# 153       Cheetah II       bad             1         1      1           1
#
#      Power  Combat  Total
# 610     72      28    288
# ...

# %%
bad_hero.sort_values(by='Intelligence',ascending=False)
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 386  Mister Mxyzptlk       bad           113        10     12          14
# 338       Lex Luthor       bad           100        10     12          14
# 336           Leader       bad           100        10     12          14
# 122         Brainiac       bad           100        28     63          90
# 194      Doctor Doom       bad           100        32     20         100
# ..               ...       ...           ...       ...    ...         ...
# 460      Redeemer II       bad             1         1      1           1
# 154      Cheetah III       bad             1         1      1           1
# 153       Cheetah II       bad             1         1      1           1
# 152        Cheetah I       bad             1         1      1           1
# 461     Redeemer III       bad             1         1      1           1
#
#      Power  Combat  Total
# 386    100      28    277
# ...

# %%
bad_hero.sort_values(by='Total',ascending=False)
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 535  Superboy-Prime       bad            94       100    100         100
# 242     General Zod       bad            94       100     96         100
# 16            Amazo       bad            75       100    100         100
# 203        Dormammu       bad            88        95     83         100
# 201        Doomsday       bad            88        80     67         120
# ..              ...       ...           ...       ...    ...         ...
# 103        Blizzard       bad             1         1      1           1
# 349   Luke Campbell       bad             1         1      1           1
# 181        Darkside       bad             1         1      1           1
# 390          Moloch       bad             1         1      1           1
# 254     Goliath III       bad             1         1      1           1
#
#      Power  Combat  Total
# 535    100      85    579
# 242     94      95    579
# ...

# %%
# Bad Alignemnt with Max  Power
bad_max_power = bad_hero.sort_values(by='Power',ascending=False)

# %%
plt.figure(figsize=(8,5))
plt.bar(list(bad_max_power['Name'])[0:5]  ,  list(bad_max_power['Total'])[0:5])
plt.show()

# %%
# Good Hero Histogram
plt.figure(figsize=(7,5))
plt.hist(good_hero['Speed'])
plt.title("Distribution of Speed")
plt.xlabel("Speed")
plt.show()

# %%
# Bad Hero Histogram
plt.figure(figsize=(7,5))
plt.hist(bad_hero['Combat'])
plt.title("Distribution of Speed")
plt.xlabel("Combat")
plt.show()

# %%
plt.figure(figsize=(7,5))
plt.bar(good_max_power['Name'][0:5] , list(good_max_power['Total'][0:5]))
plt.show()
